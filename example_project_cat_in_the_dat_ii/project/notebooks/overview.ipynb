# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# '/home/wolfgang/git/approaching_almost_any_machine_learning_problem/p73ff_arranging_with_cat_in_the_dat/project/notebooks'

# %%
pd.options.display.max_columns=100
df = pd.read_csv("../data/processed/train_folds.csv")
df
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2  \
# 0       226853    0.0    0.0    0.0     F     N    Red     Circle  Axolotl
# 1       188049    1.0    0.0    0.0     F     N   Blue    Polygon      Dog
# 2       121707    0.0    0.0    1.0   NaN     N   Blue     Circle  Axolotl
# 3       155231    NaN    1.0    0.0     F     Y   Blue   Triangle      NaN
# 4       336932    0.0    0.0    0.0     F     Y  Green   Triangle      Dog
# ...        ...    ...    ...    ...   ...   ...    ...        ...      ...
# 599995  398825    0.0    0.0    0.0     F     Y   Blue    Polygon     Lion
# 599996  545707    0.0    0.0    1.0     F     Y   Blue   Triangle  Axolotl
# 599997  302847    0.0    0.0    0.0     T     Y  Green     Square     Lion
# 599998   77185    0.0    NaN    0.0     F     N   Blue  Trapezoid  Axolotl
# 599999  194641    0.0    0.0    1.0     T     N  Green  Trapezoid  Hamster
#
# ...

# %%
df.groupby("strat_fold").agg("count").id
# Out:
# strat_fold
# 0    120000
# 1    120000
# 2    120000
# 3    120000
# 4    120000
# Name: id, dtype: int64

# %%
import seaborn as sns

sns.pairplot(df.head(1000))

# %%
df.nunique()
# Out:
# id            600000
# bin_0              2
# bin_1              2
# bin_2              2
# bin_3              2
# bin_4              2
# nom_0              3
# nom_1              6
# nom_2              6
# nom_3              6
# nom_4              4
# nom_5           1220
# nom_6           1519
# nom_7            222
# nom_8            222
# nom_9           2218
# ord_0              3
# ord_1              5
# ord_2              6
# ord_3             15
# ord_4             26
# ord_5            190
# day                7
# month             12
# target             2
# strat_fold         5
# dtype: int64
